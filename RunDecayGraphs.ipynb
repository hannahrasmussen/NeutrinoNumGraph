# %%
import DecayGraphs as DG

# %%
DG.graph_BR(5e-5)

# %%
DG.graph_mix_ms_t(250,350,1e-5,1e-4)

# %%
DG.graph_final_num(300,5e-5)
# Out:
# /Users/hannahrasmussen/Work/Most_recent_code/DES/DES/Differential_Equation_Solver_new.py:150: RuntimeWarning: invalid value encountered in true_divide
#   dx = .05*min(abs(y_in/der(xi,y_in)).any(),.001) #hopefully the derivative isn't 0 at first?
